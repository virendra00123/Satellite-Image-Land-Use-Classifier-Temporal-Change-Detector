# %% [markdown]
# # 05 — Evaluation & Analysis
#
# Spatial leakage experiment (Deliverable #6) and error analysis on the top-5 misclassified pairs (Deliverable #7).

# %%
import sys, subprocess
sys.path.append('..')
result = subprocess.run(
    ['python', '-m', 'src.spatial_leakage', '--checkpoint', 'checkpoints/transfer_resnet18.pt'],
    cwd='..', capture_output=True, text=True
)
print(result.stdout)
print(result.stderr)

# %%
from src import config
print((config.REPORT_DIR / 'spatial_leakage_writeup.txt').read_text())

# %% [markdown]
# ## Error analysis

# %%
result = subprocess.run(
    ['python', '-m', 'src.error_analysis', '--checkpoint', 'checkpoints/transfer_resnet18.pt'],
    cwd='..', capture_output=True, text=True
)
print(result.stdout)
print(result.stderr)

# %%
from PIL import Image
Image.open(config.FIGURE_DIR / 'error_analysis_top5.png')

# %%
print((config.REPORT_DIR / 'error_analysis.txt').read_text())
